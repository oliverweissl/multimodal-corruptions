# %% [markdown]
# # RQ2 --- Efficiency

# %%
import sys; sys.path.insert(0, '..')
import pandas as pd
from analysis._loader import load_all_results, success_only
from analysis._analysis import setup_matplotlib, SPLIT_LABEL, SPLIT_ORDER

setup_matplotlib()
df_all = load_all_results(include_baseline_fail=True)
df = success_only(df_all)
df['total_budget'] = (df['img_budget_used'] + df['txt_budget_used']).clip(upper=df['budget_max'])
df['budget_utilization'] = df['total_budget'] / df['budget_max']

# %%
METRIC_COLS = [
    'img_budget_used',
    'txt_budget_used',
    'total_budget',
    'total_evaluations',
    'runtime',
]

rows = []

for model in sorted(df_all['model'].unique()):
    for key in SPLIT_ORDER:
        mod, gmode, cat = key

        sub = df[
            (df['model'] == model) &
            (df['modality'] == mod) &
            (df['genome_mode'] == gmode) &
            (df['obj_category'] == cat)
        ]

        vals = []

        for col in METRIC_COLS:
            v = sub[col].dropna()

            if len(v):
                vals.append(f"${v.mean():.2f} \\pm {(0 if pd.isna(v.std()) else v.std()):.2f}$")
            else:
                vals.append("---")

        line = " & ".join([
            model,
            SPLIT_LABEL[key],
            *vals
        ]) + r" \\"

        rows.append(line)

for r in rows:
    print(r)
# Out:
# deepseek & multimodal-multi & --- & --- & --- & --- & --- \\
# deepseek & multimodal-single-multi & --- & --- & --- & --- & --- \\
# deepseek & multimodal-single-solo & --- & --- & --- & --- & --- \\
# deepseek & image-multi & --- & --- & --- & --- & --- \\
# deepseek & image-single-multi & --- & --- & --- & --- & --- \\
# deepseek & image-single-solo & --- & --- & --- & --- & --- \\
# deepseek & text-multi & --- & --- & --- & --- & --- \\
# deepseek & text-single-multi & --- & --- & --- & --- & --- \\
# deepseek & text-single-solo & --- & --- & --- & --- & --- \\
# gemma & multimodal-multi & --- & --- & --- & --- & --- \\
# gemma & multimodal-single-multi & $0.45 \pm 0.00$ & $0.00 \pm 0.00$ & $0.46 \pm 0.00$ & $90.00 \pm 0.00$ & $61.36 \pm 0.00$ \\
# gemma & multimodal-single-solo & --- & --- & --- & --- & --- \\
# gemma & image-multi & --- & --- & --- & --- & --- \\
# gemma & image-single-multi & --- & --- & --- & --- & --- \\
# gemma & image-single-solo & $0.04 \pm 0.00$ & $0.00 \pm 0.00$ & $0.04 \pm 0.00$ & $30.00 \pm 0.00$ & $5.40 \pm 0.00$ \\
# gemma & text-multi & --- & --- & --- & --- & --- \\
# gemma & text-single-multi & --- & --- & --- & --- & --- \\
# gemma & text-single-solo & $0.00 \pm 0.00$ & $0.01 \pm 0.00$ & $0.01 \pm 0.00$ & $450.00 \pm 0.00$ & $144.56 \pm 0.00$ \\
# intern & multimodal-multi & $0.26 \pm 0.28$ & $0.30 \pm 0.30$ & $0.55 \pm 0.26$ & $351.75 \pm 136.89$ & $105.99 \pm 50.72$ \\
# intern & multimodal-single-multi & $0.26 \pm 0.26$ & $0.18 \pm 0.24$ & $0.44 \pm 0.24$ & $306.00 \pm 136.28$ & $84.13 \pm 43.93$ \\
# intern & multimodal-single-solo & $0.28 \pm 0.29$ & $0.23 \pm 0.28$ & $0.51 \pm 0.25$ & $320.62 \pm 145.87$ & $82.52 \pm 49.89$ \\
# intern & image-multi & $0.43 \pm 0.28$ & $0.00 \pm 0.00$ & $0.43 \pm 0.28$ & $152.25 \pm 159.67$ & $70.07 \pm 73.23$ \\
# intern & image-single-multi & $0.34 \pm 0.24$ & $0.00 \pm 0.00$ & $0.34 \pm 0.24$ & $107.14 \pm 147.92$ & $40.96 \pm 59.17$ \\
# intern & image-single-solo & $0.36 \pm 0.22$ & $0.00 \pm 0.00$ & $0.36 \pm 0.22$ & $139.69 \pm 165.83$ & $43.44 \pm 50.83$ \\
# intern & text-multi & $0.00 \pm 0.00$ & $0.21 \pm 0.22$ & $0.21 \pm 0.22$ & $315.75 \pm 161.48$ & $28.25 \pm 16.29$ \\
# intern & text-single-multi & $0.00 \pm 0.00$ & $0.29 \pm 0.31$ & $0.29 \pm 0.31$ & $289.71 \pm 160.89$ & $20.88 \pm 12.01$ \\
# intern & text-single-solo & $0.00 \pm 0.00$ & $0.26 \pm 0.28$ & $0.26 \pm 0.28$ & $302.81 \pm 145.65$ & $18.63 \pm 9.09$ \\
# kimi & multimodal-multi & $0.22 \pm 0.20$ & $0.24 \pm 0.31$ & $0.46 \pm 0.23$ & $291.00 \pm 143.56$ & $88.46 \pm 62.57$ \\
# kimi & multimodal-single-multi & $0.17 \pm 0.24$ & $0.42 \pm 0.33$ & $0.59 \pm 0.23$ & $376.50 \pm 135.39$ & $103.42 \pm 42.16$ \\
# kimi & multimodal-single-solo & $0.25 \pm 0.20$ & $0.18 \pm 0.23$ & $0.43 \pm 0.08$ & $252.00 \pm 191.62$ & $48.69 \pm 27.96$ \\
# kimi & image-multi & $0.29 \pm 0.34$ & $0.00 \pm 0.00$ & $0.29 \pm 0.34$ & $90.00 \pm 130.38$ & $22.15 \pm 38.35$ \\
# kimi & image-single-multi & $0.25 \pm 0.26$ & $0.00 \pm 0.00$ & $0.25 \pm 0.26$ & $51.00 \pm 41.41$ & $8.88 \pm 8.29$ \\
# kimi & image-single-solo & $0.20 \pm 0.23$ & $0.00 \pm 0.00$ & $0.20 \pm 0.23$ & $30.00 \pm 0.00$ & $3.12 \pm 0.42$ \\
# kimi & text-multi & $0.00 \pm 0.00$ & $0.26 \pm 0.31$ & $0.26 \pm 0.31$ & $330.00 \pm 164.32$ & $31.92 \pm 30.41$ \\
# kimi & text-single-multi & $0.00 \pm 0.00$ & $0.16 \pm 0.24$ & $0.16 \pm 0.24$ & $244.50 \pm 179.81$ & $25.84 \pm 35.79$ \\
# kimi & text-single-solo & $0.00 \pm 0.00$ & $0.15 \pm 0.24$ & $0.15 \pm 0.24$ & $174.00 \pm 174.16$ & $7.84 \pm 6.73$ \\
# qwen & multimodal-multi & $0.14 \pm 0.17$ & $0.36 \pm 0.30$ & $0.50 \pm 0.24$ & $409.55 \pm 92.13$ & $101.01 \pm 35.13$ \\
# qwen & multimodal-single-multi & $0.18 \pm 0.24$ & $0.33 \pm 0.28$ & $0.51 \pm 0.25$ & $411.24 \pm 82.56$ & $100.49 \pm 31.06$ \\
# qwen & multimodal-single-solo & $0.12 \pm 0.18$ & $0.38 \pm 0.27$ & $0.51 \pm 0.24$ & $430.74 \pm 48.52$ & $94.85 \pm 24.42$ \\
# qwen & image-multi & $0.48 \pm 0.28$ & $0.00 \pm 0.00$ & $0.48 \pm 0.28$ & $352.27 \pm 167.02$ & $44.40 \pm 54.90$ \\
# qwen & image-single-multi & $0.46 \pm 0.27$ & $0.00 \pm 0.00$ & $0.46 \pm 0.27$ & $373.15 \pm 148.49$ & $35.42 \pm 17.50$ \\
# qwen & image-single-solo & $0.48 \pm 0.28$ & $0.00 \pm 0.00$ & $0.48 \pm 0.28$ & $441.47 \pm 51.16$ & $26.16 \pm 4.85$ \\
# qwen & text-multi & $0.00 \pm 0.00$ & $0.37 \pm 0.28$ & $0.37 \pm 0.28$ & $403.18 \pm 113.49$ & $59.88 \pm 27.95$ \\
# qwen & text-single-multi & $0.00 \pm 0.00$ & $0.39 \pm 0.30$ & $0.39 \pm 0.30$ & $412.58 \pm 94.90$ & $68.05 \pm 28.37$ \\
# qwen & text-single-solo & $0.00 \pm 0.00$ & $0.40 \pm 0.28$ & $0.40 \pm 0.28$ & $420.00 \pm 82.33$ & $63.47 \pm 26.55$ \\
