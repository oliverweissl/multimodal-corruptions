# %% [markdown]
# # RQ3 — Validity

# %%
import os, sys, warnings
warnings.filterwarnings('ignore')

ROOT = os.getcwd()
if not os.path.isdir(os.path.join(ROOT, 'results')):
    ROOT = os.path.dirname(ROOT)

if ROOT not in sys.path:
    sys.path.insert(0, ROOT)

from analysis._analysis import (
    load_rq3_data, rq3_validity_table,
    rq3_validity_by_modality, rq3_validity_by_model,
)
from analysis._loader import load_all_results, success_only

df_human = load_rq3_data(ROOT)

# All models, all modalities — needed for by-modality and by-model breakdowns
df_vlm_all = load_all_results()
df_vlm_all = success_only(df_vlm_all)

# For the scene table: qwen multimodal only (as before)
df_vlm_qwen_mm = df_vlm_all[
    (df_vlm_all['model'] == 'qwen') & (df_vlm_all['modality'] == 'multimodal')
]

MODEL_LABEL = {
    'qwen':   'Qwen3-VL',
    'kimi':   'Kimi-VL',
    'intern': 'InternVL-3.5',
}

print(f'Human: {df_human.filename.nunique()} images, {len(df_human)} sessions')
print(f'VLM (all): {len(df_vlm_all)} results across {df_vlm_all.model.nunique()} models')
# Out:
# Human: 132 images, 162 sessions
# VLM (all): 1179 results across 4 models

# %% [markdown]
# ## Validity: accept rate · human IoU · VLM IoU

# %%
t = rq3_validity_table(df_human, df_vlm_qwen_mm)
display(t)
print(t.to_latex(escape=False))
# Out:
#            N sessions Accept rate Human IoU (bbox, mean $\pm$ std)  \
# Scene
# Isolated           53       79.2%                0.874 $\pm$ 0.099
# Clustered          53       75.5%                0.850 $\pm$ 0.152
# Mixed              56       98.2%                0.657 $\pm$ 0.247
#
#           VLM IoU (post-attack, mean $\pm$ std)
# Scene
# Isolated                      0.009 $\pm$ 0.053
# Clustered                     0.049 $\pm$ 0.122
# Mixed                         0.073 $\pm$ 0.134
# \begin{tabular}{lrlll}
# \toprule
#  & N sessions & Accept rate & Human IoU (bbox, mean $\pm$ std) & VLM IoU (post-attack, mean $\pm$ std) \\
# Scene &  &  &  &  \\
# \midrule
# Isolated & 53 & 79.2% & 0.874 $\pm$ 0.099 & 0.009 $\pm$ 0.053 \\
# Clustered & 53 & 75.5% & 0.850 $\pm$ 0.152 & 0.049 $\pm$ 0.122 \\
# Mixed & 56 & 98.2% & 0.657 $\pm$ 0.247 & 0.073 $\pm$ 0.134 \\
# \bottomrule
# \end{tabular}

# %% [markdown]
# ## Validity by model

# %%
t_model = rq3_validity_by_model(df_human, df_vlm_all, model_label=MODEL_LABEL)
display(t_model)
print(t_model.to_latex(escape=False))
# Out:
#               N (VLM) Accept rate Human IoU (bbox, mean $\pm$ std)  \
# Model
# gemma               3       84.6%                0.791 $\pm$ 0.202
# InternVL-3.5      321       84.6%                0.791 $\pm$ 0.202
# Kimi-VL           105       84.6%                0.791 $\pm$ 0.202
# Qwen3-VL          750       84.6%                0.791 $\pm$ 0.202
#
#              VLM IoU (post-attack, mean $\pm$ std)
# Model
# gemma                            0.194 $\pm$ 0.167
# InternVL-3.5                     0.096 $\pm$ 0.118
# Kimi-VL                          0.018 $\pm$ 0.071
# Qwen3-VL                         0.205 $\pm$ 0.305
# \begin{tabular}{lrlll}
# \toprule
#  & N (VLM) & Accept rate & Human IoU (bbox, mean $\pm$ std) & VLM IoU (post-attack, mean $\pm$ std) \\
# Model &  &  &  &  \\
# \midrule
# gemma & 3 & 84.6% & 0.791 $\pm$ 0.202 & 0.194 $\pm$ 0.167 \\
# InternVL-3.5 & 321 & 84.6% & 0.791 $\pm$ 0.202 & 0.096 $\pm$ 0.118 \\
# Kimi-VL & 105 & 84.6% & 0.791 $\pm$ 0.202 & 0.018 $\pm$ 0.071 \\
# Qwen3-VL & 750 & 84.6% & 0.791 $\pm$ 0.202 & 0.205 $\pm$ 0.305 \\
# \bottomrule
# \end{tabular}
